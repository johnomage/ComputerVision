# %%
import cv2
import numpy as np

# %%
image = cv2.imread("C:/opencv/images/input.jpg")

# %%
cv2.imshow("Weldone Edus", image)
cv2.waitKey()
# Out:
# 32

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow("Grey Look", grey_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# Individual color level for the first pixel (0,0)

# %%
BB, GG, RR = image[0 ,0]
print(BB.max(), GG.max(), RR.max(), image.shape)
# Out:
# 12 18 31 (415, 622, 3)

# %%
# b,g,r = grey_image[0,0]
# print(b,g,r)
print(grey_image[0,0])
print(grey_image.shape)
# Out:
# 21
# (415, 622)

# %% [markdown]
# HSV image manipulation H(0-180), S(0-255), V(0-255)

# %%
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

cv2.imshow("HSV image", hsv_image)
cv2.imshow("Hue Channel", hsv_image[:, :, 0])
cv2.imshow("Saturation Channel", hsv_image[:, :, 1])
cv2.imshow("Value Channel", hsv_image[:, :, 2])

cv2.waitKey()
cv2.destroyAllWindows()

# %%
B, G, R = cv2.split(image)

print(B.shape)
cv2.imshow("Blue Channel", B)
cv2.imshow("Green Channel", G)
cv2.imshow("Red Channel", R)

merged = cv2.merge([B,G,R])
cv2.imshow("Merged", merged)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (415, 622)

# %%
zeros = np.zeros(image.shape[:2], "uint8")
cv2.imshow("Red", cv2.merge([zeros, zeros, R]))
cv2.imshow("Blue", cv2.merge([B, zeros, zeros]))
cv2.imshow("Green", cv2.merge([zeros, G, zeros]))
cv2.imshow("Merged", merged)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# Visualizing indidvidual component with histogram

# %%
from matplotlib import pyplot as plt

# %%
histogram = cv2.calcHist([image], [0], None, [256], [0, 256])
plt.hist(image.ravel(), 256, [0, 256]); plt.show()

color = ("b", "g", "r")

for i, col in enumerate(color):
    histogram2 = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(histogram2, color=col)
    plt.xlim([0, 256])

    plt.show()
